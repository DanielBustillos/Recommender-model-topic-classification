# %% [markdown]
# # Mapeo catálogo RCEA a Fronteras

# %% [markdown]
# ### Cargar datos

# %%
import pandas as pd
from joblib import load, dump
from utils import *

clasi = ["campo", "disciplina", "subdisciplina"]

# %%
df_rcea = load('data-raw/data_eval.pkl')
print(df_rcea.shape,df_rcea.columns)
df_rcea.head()
# Out:
# --------------------------------------------------------------------------
# FileNotFoundError                        Traceback (most recent call last)
# <ipython-input-2-fe666c4aa6a8> in <module>
# ----> 1 df_rcea = load('data-raw/data_eval.pkl')
#       2 print(df_rcea.shape,df_rcea.columns)
#       3 df_rcea.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/numpy_pickle.py in load(filename, mmap_mode)
#     588             obj = _unpickle(fobj)
#     589     else:
# --> 590         with open(filename, 'rb') as f:
#     591             with _read_fileobject(f, filename, mmap_mode) as fobj:
#     592                 if isinstance(fobj, _basestring):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data-raw/data_eval.pkl'

# %%
df_eval = pd.read_csv("data-raw/propuesta_evaluador_201911121032.csv", dtype=object)
print(df_eval.shape, df_eval.columns)
df_eval = df_eval[['rcea', 'proyecto_id'] + clasi]
df_eval.head()
# Out:
# --------------------------------------------------------------------------
# FileNotFoundError                        Traceback (most recent call last)
# <ipython-input-3-03b35c7c7909> in <module>
# ----> 1 df_eval = pd.read_csv("data-raw/propuesta_evaluador_201911121032.csv", dtype=object)
#       2 print(df_eval.shape, df_eval.columns)
#       3 df_eval = df_eval[['rcea', 'proyecto_id'] + clasi]
#       4 df_eval.head()
#
# ...

# %% [markdown]
# ### Evaluar ambos conjuntos
#
# Se ignora la estructura jerarquica de ambos catalogos y solo se busca el caso que coincida mejor en cuanto al texto

# %% [markdown]
# Tamaño de los catalogos

# %%
for col in clasi:
    print(col, df_eval[col].nunique(), df_rcea[col].nunique())
# Out:
# campo 52 55
# disciplina 464 515
# subdisciplina 1214 1988

# %% [markdown]
# Evaluacion de la calidad de los mapeos
#
# Solo correr en caso de emergencia

# %% [markdown]
# dics_mapeo_rcea_eval = {}
# for col in clasi:
#     datos = df_rcea[col].dropna().unique().tolist()
#     catalogo = df_eval[col].dropna().unique().tolist()
#     dics_mapeo_rcea_eval[col] = generar_diccionario_mapeo(datos, catalogo, warn=0)
# dics_mapeo_eval_rcea = {}
# for col in clasi:
#     catalogo = df_rcea[col].dropna().unique().tolist()
#     datos = df_eval[col].dropna().unique().tolist()
#     dics_mapeo_eval_rcea[col] = generar_diccionario_mapeo(datos, catalogo, warn=0)

# %% [markdown]
# print('rcea->eval')
# for col in clasi:
#     print(col, '\tcobertura:', round(len([1 for k,v in dics_mapeo_rcea_eval[col].items() if k!=v])/len(dics_mapeo_rcea_eval[col]),3) )
# print('eval->rcea')
# for col in clasi:
#     print(col, '\tcobertura:', round(len([1 for k,v in dics_mapeo_eval_rcea[col].items() if k!=v])/len(dics_mapeo_eval_rcea[col]),3) )

# %% [markdown]
# ```
# rcea->eval
# campo 	cobertura: 1.0
# disciplina 	cobertura: 1.0
# subdisciplina 	cobertura: 1.0
# eval->rcea
# campo 	cobertura: 1.0
# disciplina 	cobertura: 1.0
# subdisciplina 	cobertura: 1.0
# ```
#
# En base a esto se usara el mapeo rcea -> fronteras

# %%
dics_mapeo_rcea_eval = {}

# %% [markdown]
# mapeo automatico

# %%
col = 'campo'
datos = df_rcea[col].dropna().unique().tolist()
catalogo = df_eval[col].dropna().unique().tolist()
dics_mapeo_rcea_eval[col] = generar_diccionario_mapeo(datos, catalogo, warn=95, limit=90, max_opciones=5)
# Out:
# C:\Users\CONACYT\Documents\Evaluadores_RCEA\utils.py:71: UserWarning: IGNORADO: ciencias de la salud.
# 	Opciones: medios de comunicacion y comunicaciones (86), ciencias de las artes y las letras (86), ciencias de la tierra y del espacio (86), ciencias de la vida (82), ciencias de la educacion (78)
#   warnings.warn( warn_message )
# C:\Users\CONACYT\Documents\Evaluadores_RCEA\utils.py:71: UserWarning: BAJA SIMILITUD: ciencias politicas.
# 	Opciones: ciencia politica (94), ciencias de las artes y las letras (86), ciencias de la tierra y del espacio (86), ciencias juridicas y derecho (86), ciencias tecnologicas (77)
#   warnings.warn( warn_message )
# C:\Users\CONACYT\Documents\Evaluadores_RCEA\utils.py:71: UserWarning: IGNORADO: ciencias de la tierra y del cosmos.
# 	Opciones: ciencias de la tierra y del espacio (87), ciencias medicas (86), estudios de genero (86), arte y cultura (86), ciencias del mar (86)
#   warnings.warn( warn_message )
# ...

# %% [markdown]
# correcion manual

# %%
dics_mapeo_rcea_eval[col]['ciencias politicas'] = 'ciencia politica '
dics_mapeo_rcea_eval[col]['ciencias de la tecnologia'] = 'ciencias tecnologicas'
dics_mapeo_rcea_eval[col]['ciencias agronomicas y veterinarias'] = 'ciencias agrarias '
dics_mapeo_rcea_eval[col]['ciencias de la ocupacion'] = 'ciencias de la educacion '
dics_mapeo_rcea_eval[col]['ciencias de la tierra y del cosmos'] = 'ciencias de la tierra y del espacio'

# %% [markdown]
# mapeo automatico

# %%
col = 'disciplina'
datos = df_rcea[col].dropna().unique().tolist()
catalogo = df_eval[col].dropna().unique().tolist()
dics_mapeo_rcea_eval[col] = generar_diccionario_mapeo(datos, catalogo, warn=95, limit=90, max_opciones=5)
print(col, 'cobertura:', round(len([1 for k,v in dics_mapeo_rcea_eval[col].items() if k!=v])/len(dics_mapeo_rcea_eval[col]),3) )
# Out:
# C:\Users\CONACYT\Documents\Evaluadores_RCEA\utils.py:71: UserWarning: IGNORADO: biblioteconomia y archivonomia.
# 	Opciones: salud y genero (86), genetica y evolucion (86), estudios y procesos creativos en arte y diseno (86), historia y filosofia de la ciencia y tecnologia (86), medios de comunicacion y comunicacion socio cultural (86)
#   warnings.warn( warn_message )
# C:\Users\CONACYT\Documents\Evaluadores_RCEA\utils.py:71: UserWarning: IGNORADO: espacios y materia interplanetarios.
# 	Opciones: salud y genero (86), genetica y evolucion (86), negocios y contabilidad (86), polimeros y materiales (86), peces y fauna silvestre (86)
#   warnings.warn( warn_message )
# C:\Users\CONACYT\Documents\Evaluadores_RCEA\utils.py:71: UserWarning: IGNORADO: tecnologia de la metalurgia.
# ...

# %% [markdown]
# correcion manual

# %%
dics_mapeo_rcea_eval[col]['tecnologia e ingenieria aeronautica'] = 'ingenieria y tecnologia aeronauticas'
dics_mapeo_rcea_eval[col]['farmacobiologia'] = 'farmacologia'
dics_mapeo_rcea_eval[col]['historia de las epocas'] = 'tamano de la poblacion y evolucion demografica'
dics_mapeo_rcea_eval[col]['fisicoquimica'] = 'quimica fisica'
dics_mapeo_rcea_eval[col]['demografia historica'] = 'geografia historica'
dics_mapeo_rcea_eval[col]['otras especialidades en materia de matematicas.'] = 'otras especialidades matematicas'
dics_mapeo_rcea_eval[col]['historia especializada'] = 'historia por especialidades'
dics_mapeo_rcea_eval[col]['ciencias atmosfericas'] = ' ciencias de la atmosfera '
dics_mapeo_rcea_eval[col]['sociologia de actividades particulares'] = 'estudios de area'
dics_mapeo_rcea_eval[col]['otras especialidades en materia de antropologia'] = ' historia por especialidades'
dics_mapeo_rcea_eval[col]['analisis de las operaciones tecnologicas'] = 'analisis numerico'
dics_mapeo_rcea_eval[col]['logica general'] = 'aplicaciones de la logica'
dics_mapeo_rcea_eval[col]['otras especialidades en materia de psicologia.'] = 'psicologia general'
dics_mapeo_rcea_eval[col]['teorias y metodos juridicos generales'] = 'administracion y gestion'
dics_mapeo_rcea_eval[col]['tecnologia textil'] = 'ingenieria y tecnologia quimicas'
dics_mapeo_rcea_eval[col]['fisica nuclear'] = 'fisica atomica y nuclear'
dics_mapeo_rcea_eval[col]['linguistica teorica'] = 'teoria linguistica'
dics_mapeo_rcea_eval[col]['evaluacion y medicion psicologicas'] = 'evaluacion y medicion psicologicas'
dics_mapeo_rcea_eval[col]['analisis de riesgos'] = 'tamano de la poblacion y evolucion demografica'
dics_mapeo_rcea_eval[col]['otras especialidades en materia de histori'] = 'historia por epocas'
dics_mapeo_rcea_eval[col]['otras especialidades en materia de pedagogia'] = 'sociologia de la educacion'
dics_mapeo_rcea_eval[col]['otras especialidades en materia de tecnologia.'] = 'tecnologia metalurgica'
dics_mapeo_rcea_eval[col]['filosofia de la naturaleza'] = 'biosistematica y manejo de recursos naturales'
dics_mapeo_rcea_eval[col]['sanidad publica'] = 'salud publica'
dics_mapeo_rcea_eval[col]['entomologia general'] = 'biologia de insectos entomologia'
dics_mapeo_rcea_eval[col]['prevision'] = 'radiacion'
dics_mapeo_rcea_eval[col]['arquitectura planeacion regional o urbana'] = 'planificacion urbana'
dics_mapeo_rcea_eval[col]['psicologia de la educacion'] = 'educacion'
dics_mapeo_rcea_eval[col]['psicologia patologica'] = 'evaluacion y diagnostico en psicologia '
dics_mapeo_rcea_eval[col]['sociologia de la politica'] = 'sociologia politica'
dics_mapeo_rcea_eval[col]['actividades economicas'] = 'actividad economica'
dics_mapeo_rcea_eval[col]['antropologia estructural'] = ' antropologia cultural'
dics_mapeo_rcea_eval[col]['fisica de las particulas nucleares'] = 'fisica teorica'
dics_mapeo_rcea_eval[col]['organizacion y planificacion pedagogicas'] = 'teoria y metodos generales'
dics_mapeo_rcea_eval[col][' psicologia del trabajo y del personal'] = 'administracion y gestion'
dics_mapeo_rcea_eval[col]['unidades y constantes fisicas'] = ' unidades y constantes'
dics_mapeo_rcea_eval[col]['administracion de hospitales y de la atencion medica.'] = 'administracion y gestion'
dics_mapeo_rcea_eval[col][' contabilidad publica'] = 'contabilidad economica'
dics_mapeo_rcea_eval[col]['politicas sectoriales'] = 'ciencias politicas'
dics_mapeo_rcea_eval[col]['tecnologia del petroleo y del carbon'] = 'tecnologia del carbon y del petroleo'
dics_mapeo_rcea_eval[col]['caracteristicas de las poblaciones'] = 'caracteristicas de la poblacion'
dics_mapeo_rcea_eval[col]['tecnologia de los vehiculos de motor'] = 'tecnologia de vehiculos de motor'
dics_mapeo_rcea_eval[col]['orientacion psicologica'] = 'psicologia experimental'
dics_mapeo_rcea_eval[col]['otras especialidades en materia de biologia'] = 'otras especialidades de la biologia'
dics_mapeo_rcea_eval[col]['politica fiscal y hacienda publica nacional'] = 'politica fiscal y hacienda publica'
dics_mapeo_rcea_eval[col]['cambio economico o tecnologico'] ='economia del cambio tecnologico'
dics_mapeo_rcea_eval[col]['tecnologia del medio ambiente'] = 'ingenieria y tecnologia del medio ambiente'
dics_mapeo_rcea_eval[col]['filosofia de los conocimientos'] = 'filosofia del conocimiento'
dics_mapeo_rcea_eval[col]['investigacion en salud'] = 'investigacion medica linea terminal biomedicina'
dics_mapeo_rcea_eval[col]['politica teorica'] = 'teoria politica'
dics_mapeo_rcea_eval[col]['logica inductiva'] = 'aplicaciones de la logica'
dics_mapeo_rcea_eval[col]['teoria de los numeros'] = 'teoria de numeros'
dics_mapeo_rcea_eval[col]['quimica agronomica'] = 'quimica de recursos naturales '
dics_mapeo_rcea_eval[col]['historia de los paises'] = 'historia de paises'
dics_mapeo_rcea_eval[col]['biologia de la reproduccion humana'] = ' biologia integrativa'
dics_mapeo_rcea_eval[col]['otras especialidades en materia de ciencias agronomicas y veterinarias'] = 'biosistematica y manejo de recursos naturales'
dics_mapeo_rcea_eval[col]['oceanologia'] = 'oceanografia'

# %% [markdown]
# mapeo automatico

# %%
col = 'subdisciplina'
datos = df_rcea[col].dropna().unique().tolist()
catalogo = df_eval[col].dropna().unique().tolist()
dics_mapeo_rcea_eval[col] = generar_diccionario_mapeo(datos, catalogo, warn=95, limit=90, max_opciones=5)
print(col, 'cobertura:', round(len([1 for k,v in dics_mapeo_rcea_eval[col].items() if k!=v])/len(dics_mapeo_rcea_eval[col]),3) )
# Out:
# C:\Users\CONACYT\Documents\Evaluadores_RCEA\utils.py:71: UserWarning: IGNORADO: asentamientos urbanos.
# 	Opciones: nutrientes (63), revestimientos hidrofobos (61), antigenos (60), diseno (60), lentes (60)
#   warnings.warn( warn_message )
# C:\Users\CONACYT\Documents\Evaluadores_RCEA\utils.py:71: UserWarning: IGNORADO: desempeno y fiabilidad.
# 	Opciones: maquinarias y procesos de joyeria (86), movilidad y migraciones interiores (86), susceptibilidad y resistencia vegetal (86), enfermeria en geriatria y en gerontologia (86), estudios y procesos creativos en arte y diseno (86)
#   warnings.warn( warn_message )
# C:\Users\CONACYT\Documents\Evaluadores_RCEA\utils.py:71: UserWarning: IGNORADO: etnologia.
# 	Opciones: etnoecologia (86), metrologia (84), petrologia (84), etimologia (84), reologia (82)
#   warnings.warn( warn_message )
# C:\Users\CONACYT\Documents\Evaluadores_RCEA\utils.py:71: UserWarning: IGNORADO: algebra homologica.
# ...

# %% [markdown]
# correcion manual

# %%
dics_mapeo_rcea_eval[col]['reacciones y dispersion nucleares'] = 'reaccion nuclear y dispersion  '
dics_mapeo_rcea_eval[col]['ecuaciones integrodiferenciales'] = 'ecuaciones diferenciales'
dics_mapeo_rcea_eval[col]['relaciones comerciales internacionales'] = 'comercio'
dics_mapeo_rcea_eval[col]['quimica del carbonio'] = 'quimica de los hidratos de carbono'
dics_mapeo_rcea_eval[col]['cuestiones metodologicas'] = 'metodologia'
dics_mapeo_rcea_eval[col]['contabilidad administrativa'] = 'gestion administrativa'
dics_mapeo_rcea_eval[col]['microbiologia de los suelos'] = ' microbiologia de suelos'
dics_mapeo_rcea_eval[col]['transformadas integrales'] = ' ecuaciones integrales  '
dics_mapeo_rcea_eval[col]['histologia humana'] = 'fisiologia humana '
dics_mapeo_rcea_eval[col][' computadores digitales.'] = 'sistemas digitales  '
dics_mapeo_rcea_eval[col][' medio ambiente urbano'] = 'politica del medio ambiente '
dics_mapeo_rcea_eval[col]['contabilidad fiscal'] = 'contabilidad administrativa '
dics_mapeo_rcea_eval[col]['metabolismo intermedio'] = 'metabolismo intermediario '
dics_mapeo_rcea_eval[col]['ecuaciones diferenciales parciales'] = 'ecuaciones diferenciales '
dics_mapeo_rcea_eval[col]['nucleos'] = 'estructura nuclear'
dics_mapeo_rcea_eval[col]['hidrografia'] = 'hidrologia'
dics_mapeo_rcea_eval[col]['algebra diferencial'] = 'ecuaciones diferenciales'
dics_mapeo_rcea_eval[col]['liderazgo politico'] = 'historia de las ideas politicas' 
dics_mapeo_rcea_eval[col]['productos petroquimicos'] = 'petroquimica' 
dics_mapeo_rcea_eval[col]['motores electricos'] = 'conductores electricos' 
dics_mapeo_rcea_eval[col]['integracion economica'] = 'teoria de la planificacion economica' 
dics_mapeo_rcea_eval[col]['propiedades termodinamicas de los solidos'] = 'propiedades termicas de los solidos ' 
dics_mapeo_rcea_eval[col]['transicion demografica'] = 'analisis demografico' 
dics_mapeo_rcea_eval[col]['psicologia evolutiva'] = ' biologia evolutiva' 
dics_mapeo_rcea_eval[col]['electricidad'] = 'ingenieria electrica' 
dics_mapeo_rcea_eval[col]['calculo demografico'] = 'analisis demografico'
dics_mapeo_rcea_eval[col]['evaluacion de los medicamentos'] = 'evaluacion de medicamentos'
dics_mapeo_rcea_eval[col]['etnologia'] = 'etnoecologia'
dics_mapeo_rcea_eval[col]['equilibrios de fase'] = 'equilibrio de fases'
dics_mapeo_rcea_eval[col]['mineralogia de los suelos'] = 'mineralogia de suelos'
dics_mapeo_rcea_eval[col]['control de la contaminacion del aire'] = 'contaminacion'
dics_mapeo_rcea_eval[col]['telefono'] = 'telefonia'
dics_mapeo_rcea_eval[col]['poblacion activa'] = 'estadistica de poblaciones'
dics_mapeo_rcea_eval[col]['metodologia de la investigacion'] = 'metodologia de investigacion'
dics_mapeo_rcea_eval[col]['paises en desarrollo'] = 'paises en via de desarrollo'
dics_mapeo_rcea_eval[col]['funcion cerebral'] = 'actividad cerebral'
dics_mapeo_rcea_eval[col]['operaciones mecanizadas'] = 'aplicaciones mecanizadas'
dics_mapeo_rcea_eval[col]['resistencia de los materiales'] = 'resistencia de materiales'
dics_mapeo_rcea_eval[col]['quimica de los monomeros'] = 'quimica de monomeros '
dics_mapeo_rcea_eval[col]['inversiones internacionales'] = 'financiacion internacional'
dics_mapeo_rcea_eval[col]['dispositivos de semiconductores'] = 'dispositivos semiconductores '
dics_mapeo_rcea_eval[col]['salud profesional'] = 'enfermeria en salud publica'
dics_mapeo_rcea_eval[col]['poder legislativo'] = 'legislacion'
dics_mapeo_rcea_eval[col]['espectroscopia raman'] = 'espectroscopia'
dics_mapeo_rcea_eval[col]['fotoelectricidad'] = 'electricidad'
dics_mapeo_rcea_eval[col]['algebra lineal'] = 'algebra diferencial'
dics_mapeo_rcea_eval[col]['geometrias no euclideas'] = 'geometrias no euclidianas'
dics_mapeo_rcea_eval[col]['superconductividad'] = 'superconductores'
dics_mapeo_rcea_eval[col]['geometria afin'] = 'geometrias no euclidianas '
dics_mapeo_rcea_eval[col][' haces atomicos'] = 'iones atomicos'
dics_mapeo_rcea_eval[col]['dinamica poblaciones'] = 'dinamica de las poblaciones'
dics_mapeo_rcea_eval[col]['mercadeo'] = 'estudios de mercado'
dics_mapeo_rcea_eval[col]['acuerdos monetarios internacionales'] = 'operaciones comerciales internacionales'
dics_mapeo_rcea_eval[col]['meteorologia sinoptica'] = 'meteorologia tropical'
dics_mapeo_rcea_eval[col]['materialismo dialectico'] = 'teoria'
dics_mapeo_rcea_eval[col]['linguistica descriptiva'] = 'linguistica historica'
dics_mapeo_rcea_eval[col]['alimentos proteicos'] = 'alimentos proteinicos'
dics_mapeo_rcea_eval[col]['crecimiento cristalino'] = 'crecimiento de cristales'
dics_mapeo_rcea_eval[col]['residuos industriales'] = 'desechos industriales'
dics_mapeo_rcea_eval[col]['espacios lineales topologicos'] = 'grupos topologicos'
dics_mapeo_rcea_eval[col]['buques mercantes'] = 'mercadeo'
dics_mapeo_rcea_eval[col]['metodos iterativos'] = 'otra'
dics_mapeo_rcea_eval[col]['organizaciones internacionales'] = 'asuntos internacionales'
dics_mapeo_rcea_eval[col]['lexicologia'] = 'lexicografia'
dics_mapeo_rcea_eval[col]['metabolismos humanos'] = 'metabolismo humano'
dics_mapeo_rcea_eval[col]['etica economica'] = 'metodologia economica'
dics_mapeo_rcea_eval[col]['reticulos'] = 'polimeros reticulado'
dics_mapeo_rcea_eval[col]['analisis de los polimeros'] = 'analisis de polimeros'
dics_mapeo_rcea_eval[col]['escultura'] = 'estudios culturales'
dics_mapeo_rcea_eval[col]['viviendas'] = 'vivienda'
dics_mapeo_rcea_eval[col]['comportamiento organizacional'] = 'comportamiento en la organizacion'
dics_mapeo_rcea_eval[col]['exploracion geofisica'] = ' geofisica de la masa solida terrestre'
dics_mapeo_rcea_eval[col]['porcicultura'] = 'agricultura'
dics_mapeo_rcea_eval[col]['leptones'] = ' cuestiones metodologicas'
dics_mapeo_rcea_eval[col]['relaciones interraciales'] = ' historia de las relaciones internacionales'
dics_mapeo_rcea_eval[col]['analisis multivariante'] = ' analisis realizacion de modelos y planificacion estadistica'
dics_mapeo_rcea_eval[col]['maquinaria agricola'] = 'mecanica agricola'
dics_mapeo_rcea_eval[col]['mecanica continua'] = 'mecanica de medios continuos'
dics_mapeo_rcea_eval[col]['politica industrial'] = 'politica cientifica y tecnologica'
dics_mapeo_rcea_eval[col]['elastomeros'] = 'plasticos'
dics_mapeo_rcea_eval[col]['servicios publicos'] = 'servicios comunitarios sociales e individuales '
dics_mapeo_rcea_eval[col]['analisis de los productos farmaceuticos'] = 'accion de los medicamentos'
dics_mapeo_rcea_eval[col]['computadores hibridos'] = 'computadores digitales'
dics_mapeo_rcea_eval[col]['alergias'] = 'bacterias'
dics_mapeo_rcea_eval[col]['seguimiento espacial'] = 'educacion especial'
dics_mapeo_rcea_eval[col]['estudio de mercados'] = 'estudios de mercado'
dics_mapeo_rcea_eval[col]['utilizacion de la tierra'] = 'biosistematica y manejo de recursos naturales'
dics_mapeo_rcea_eval[col]['evolucion cultural'] = 'evolucion de las sociedades'
dics_mapeo_rcea_eval[col]['fisica de polimeros'] = 'quimica fisica de polimeros'
dics_mapeo_rcea_eval[col]['analisis experimental del comportamiento'] = 'analisis estadistic'
dics_mapeo_rcea_eval[col]['teoria del empleo y modelos de empleo'] = 'teoria y modelos de empleo'
dics_mapeo_rcea_eval[col]['administracion industrial'] = 'planificacion industrial'
dics_mapeo_rcea_eval[col]['desintegracion nuclear'] = 'fisica nuclear experimental bajas energias'
dics_mapeo_rcea_eval[col]['medida de las propiedades mecanicas'] = 'medida de propiedades mecanicas'
dics_mapeo_rcea_eval[col]['psicologia escolar'] = 'psicologia evolutiva'
dics_mapeo_rcea_eval[col]['programacion lineal'] = 'otra'
dics_mapeo_rcea_eval[col]['ingenieria estructural'] = 'ingenieria de estructuras'
dics_mapeo_rcea_eval[col]['difusion en los solidos'] = 'difusion en solidos'
dics_mapeo_rcea_eval[col]['fisica del suelo'] = 'fisica del suelo'
dics_mapeo_rcea_eval[col]['ensenanza programada'] = ' otra '
dics_mapeo_rcea_eval[col]['administracion de los servicios de salu'] = 'etica de la ciencia'
dics_mapeo_rcea_eval[col]['diferenciacion numerica'] = 'ecuaciones en diferencias'
dics_mapeo_rcea_eval[col]['fisica del plasma'] = 'fisica de plasmas'
dics_mapeo_rcea_eval[col]['procesos mirocrobianos'] = 'procesos microbianos'
dics_mapeo_rcea_eval[col]['aplicaciones de los isotopos'] = 'isotopos'
dics_mapeo_rcea_eval[col]['fuentes de energia no convencionales'] = 'fuentes no convencionales de energia'
dics_mapeo_rcea_eval[col]['geografia de las actividades economicas'] = 'geografia de las actividades'
dics_mapeo_rcea_eval[col]['regulacion gubernamental del sector privado'] = 'reglamentacion gubernamental del sector privado'
dics_mapeo_rcea_eval[col]['artesania'] = 'artesania'
dics_mapeo_rcea_eval[col]['arteriosclerosis'] = 'bacteriologia'
dics_mapeo_rcea_eval[col]['economia monetaria'] = 'teoria monetaria'
dics_mapeo_rcea_eval[col]['poder ejecutivo'] = ' poder judicial'
dics_mapeo_rcea_eval[col]['maquinaria industrial especializada'] = 'seguridad industrial'
dics_mapeo_rcea_eval[col]['archivonomia'] = 'archivistica'
dics_mapeo_rcea_eval[col]['radiodifusion sonora y televisiva'] = 'disenos y sistemas'
dics_mapeo_rcea_eval[col]['microelectronica diseno'] = 'microelectronica'
dics_mapeo_rcea_eval[col]['maquinaria industrial'] = 'equipo y maquinaria industrial'
dics_mapeo_rcea_eval[col]['funciones de una variable compleja'] = 'funciones de varias variables complejas'
dics_mapeo_rcea_eval[col]['quimica de los organofosforos'] = 'tecnicas de cultivo'
dics_mapeo_rcea_eval[col]['arquitectura de procesadores'] = 'arquitectura de ordenadores'
dics_mapeo_rcea_eval[col]['biotecnologia marina'] = 'ecologia marina'
dics_mapeo_rcea_eval[col]['algebras y espacios de banach'] = 'espacios y algebras de banach'
dics_mapeo_rcea_eval[col]['funcion publica'] = 'funciones especiales'
dics_mapeo_rcea_eval[col]['tecnologia de las aguas cloacales'] = 'aguas subterraneas'
dics_mapeo_rcea_eval[col]['interaccion aire mar'] = 'aire suelo y aguas subterraneas'
dics_mapeo_rcea_eval[col]['frutas'] = 'fruticultura'
dics_mapeo_rcea_eval[col]['relaciones entre los poderes'] = 'problemas de las relaciones internacionales'
dics_mapeo_rcea_eval[col]['programas matematicos'] = 'otra'
dics_mapeo_rcea_eval[col]['resonancia magnetica nuclear'] = 'espectroscopia de resonancia magnetica'
dics_mapeo_rcea_eval[col]['dinamica de la atmosfera'] = 'quimica de la atmosfera'
dics_mapeo_rcea_eval[col]['contabilidad financiera'] = 'contabilidad administrativa'
dics_mapeo_rcea_eval[col]['linguistica informatizadalinguistica informatizada'] = 'otra '
dics_mapeo_rcea_eval[col]['marketing comercializacion'] = 'comercio'
dics_mapeo_rcea_eval[col]['lengua y literatura'] = 'lenguaje y literatura'
dics_mapeo_rcea_eval[col]['finanzas internacionales'] = 'operaciones comerciales internacionales'
dics_mapeo_rcea_eval[col]['proteccion de cultivos'] = 'proteccion de los cultivos'
dics_mapeo_rcea_eval[col]['composito'] = 'materiales compuestos'
dics_mapeo_rcea_eval[col]['dinamica topologica'] = 'topologia diferencial'
dics_mapeo_rcea_eval[col]['discriminacion'] = 'migracion'
dics_mapeo_rcea_eval[col]['sintesis de las macromoleculas'] = 'sintesis de macromoleculas'
dics_mapeo_rcea_eval[col]['sonidos subacuaticos'] = 'agua'
dics_mapeo_rcea_eval[col]['geometria euclidea'] = 'geometrias no euclidianas'
dics_mapeo_rcea_eval[col]['folklore'] = 'desarrollo regional'
dics_mapeo_rcea_eval[col]['alta temperatura'] = 'geoquimica de las altas temperaturas'
dics_mapeo_rcea_eval[col]['mecanismos de reacciones inorganicas'] = 'mecanismos de las reacciones inorganicas'
dics_mapeo_rcea_eval[col]['fisica solar'] = 'fisica nuclear experimental bajas energias'
dics_mapeo_rcea_eval[col]['excavaciones'] = 'vibraciones'
dics_mapeo_rcea_eval[col]['maquinaria y equipo industriales'] = 'equipo y maquinaria industrial'
dics_mapeo_rcea_eval[col]['movilidad y migraciones internas'] = 'movilidad y migraciones internacionales'
dics_mapeo_rcea_eval[col]['simbolismo'] = 'simbolos'
dics_mapeo_rcea_eval[col]['retraso mental'] = 'otras'

# %% [markdown]
# Guardar

# %%
dump(dics_mapeo_rcea_eval, "data-clean/dics_mapeo_rcea_eval.pkl")
