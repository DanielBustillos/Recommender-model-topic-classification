# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from joblib import load, dump

# %% [markdown]
# # Objetivo: Sacar promedio y varianza de proyectos de un mismo evaluador

# %%
df_proyectos_eval_ = load("./matriz_tfidf_documento.pkl")
df_proyectos_eval_.head()
# Out:
#        CVU  ID_PROYECTO    0         1         2         3         4    5  \
# 2999     2       153467  0.0  0.000000  0.000000  0.177875  0.000000  0.0
# 2892     3       236034  0.0  0.000000  0.000000  0.000000  0.093948  0.0
# 2891     3        97976  0.0  0.000000  0.000000  0.219307  0.000000  0.0
# 2893     3       178734  0.0  0.000000  0.030672  0.000000  0.057827  0.0
# 12420    7       178526  0.0  0.098916  0.098772  0.000000  0.000000  0.0
#
#          6         7  ...       240      241  242  243       244       245  \
# 2999   0.0  0.000000  ...  0.000000  0.09168  0.0  0.0  0.094562  0.173041
# 2892   0.0  0.000000  ...  0.000000  0.00000  0.0  0.0  0.000000  0.000000
# 2891   0.0  0.000000  ...  0.000000  0.00000  0.0  0.0  0.000000  0.000000
# 2893   0.0  0.058511  ...  0.092875  0.03100  0.0  0.0  0.063949  0.000000
# 12420  0.0  0.000000  ...  0.000000  0.00000  0.0  0.0  0.000000  0.000000
#
#             246       247  248      249
# ...

# %% [markdown]
# # REALIZAR UN FOR PARA TODOS LOS CVU

# %%
    lista_mean = []
    lista_var = []
    lista_eval_selec = df_proyectos_eval_["CVU"].unique()
    
    
    for CVU in lista_eval_selec:
        coincidencia_cvu_train_test = df_proyectos_eval_[df_proyectos_eval_["CVU"]==CVU]
        cs = cosine_similarity(
            coincidencia_cvu_train_test.iloc[:,2:], 
            coincidencia_cvu_train_test.iloc[:,2:])

        cs=cs[cs<1]
        cs_mean=cs.mean()
        cs_var=cs.var()

        lista_mean.append(cs_mean)
        lista_var.append(cs_var)

    
    #Convertir a Dataframe
    zippedList =  list(zip(lista_evaluadores, lista_mean, lista_var))
    dfObj = pd.DataFrame(zippedList, columns = ['CVU' , 'Promedio', 'Varianza'])
# Out:
# /home/paw/software/python/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: Mean of empty slice.
#   del sys.path[0]
# /home/paw/software/python/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/paw/software/python/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: Degrees of freedom <= 0 for slice
#
# /home/paw/software/python/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/paw/software/python/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ...

# %%
df_proyectos_eval_ = load("./archivos/matriz_tfidf_documento.pkl")
df_proyectos_eval_.head()
# Out:
#        CVU  ID_PROYECTO    0         1         2         3         4    5  \
# 2999     2       153467  0.0  0.000000  0.000000  0.177875  0.000000  0.0
# 2892     3       236034  0.0  0.000000  0.000000  0.000000  0.093948  0.0
# 2891     3        97976  0.0  0.000000  0.000000  0.219307  0.000000  0.0
# 2893     3       178734  0.0  0.000000  0.030672  0.000000  0.057827  0.0
# 12420    7       178526  0.0  0.098916  0.098772  0.000000  0.000000  0.0
#
#          6         7  ...       240      241  242  243       244       245  \
# 2999   0.0  0.000000  ...  0.000000  0.09168  0.0  0.0  0.094562  0.173041
# 2892   0.0  0.000000  ...  0.000000  0.00000  0.0  0.0  0.000000  0.000000
# 2891   0.0  0.000000  ...  0.000000  0.00000  0.0  0.0  0.000000  0.000000
# 2893   0.0  0.058511  ...  0.092875  0.03100  0.0  0.0  0.063949  0.000000
# 12420  0.0  0.000000  ...  0.000000  0.00000  0.0  0.0  0.000000  0.000000
#
#             246       247  248      249
# ...

# %%
lista_mean = []
lista_var = []

def ProVar(dfObj):
        
    for CVU in dfObj:    
        coincidencia_cvu_train_test = dfObj[dfObj["CVU"]== CVU]
        cs = cosine_similarity(
            coincidencia_cvu_train_test.iloc[:,2:], 
            coincidencia_cvu_train_test.iloc[:,2:])

    cs=cs[cs<1]
    cs_mean=cs.mean()
    cs_var=cs.var()

    lista_mean.append(cs_mean)
    lista_var.append(cs_var)

    #Convertir a Dataframe
    zippedList =  list(zip(lista_evaluadores, lista_mean, lista_var))
    dfObj = pd.DataFrame(zippedList, columns = ['CVU' , 'Promedio', 'Varianza']) 

    return dfObj

# %%
ProVar(df_proyectos_eval_)
# Out:
# C:\Users\CONACYT\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-82a7dc6c87d6> in <module>
# ----> 1 ProVar(df_proyectos_eval_)
#
# <ipython-input-5-f555c33ce82b> in ProVar(dfObj)
#       8         cs = cosine_similarity(
#       9             coincidencia_cvu_train_test.iloc[:,2:],
# ---> 10             coincidencia_cvu_train_test.iloc[:,2:])
#      11
#      12     cs=cs[cs<1]
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in cosine_similarity(X, Y, dense_output)
#     894     # to avoid recursive import
#     895
# --> 896     X, Y = check_pairwise_arrays(X, Y)
#     897
#     898     X_normalized = normalize(X, copy=True)
#
# ...

# %%
n_daniel = 9
entero(n_daniel)
# Out:
# 'entero'

# %%
    if cs < 1:
        print(cs)
    elif cs > 1:
        del cs
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-5c7bdd3d4649> in <module>
# ----> 1 if cs < 1:
#       2     print(cs)
#       3 elif cs > 1:
#       4     del cs
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ### Guarda archivo

# %%
#dump(dfObj,'Evaluadores-Promedio.pkl')
